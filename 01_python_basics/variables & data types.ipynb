# %%
#create two variables & print their sum, difference, product and division
a=10
b=95
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 105
# -85
# 0.10526315789473684
# 950

# %%
#swap the values of two variables without using a third variable
a, b= b, a
print (f"a:{a}, b:{b}")

'''Create a string variable name = "Aimen" 
Print "Hello, Aimen!" using this variable.
Print the length of the string.
Convert it to uppercase''' 

name= "Aimen" 
print(f"Hello! {name}")
print(len(name))
print(name.upper())
# Out:
# a:10, b:95
# Hello! Aimen
# 5
# AIMEN
