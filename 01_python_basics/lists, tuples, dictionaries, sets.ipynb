# %%
""" Create a list of 5 numbers.

Print the largest and smallest number.

Append a new number to the list.

Remove the second number."""
l=[56, 28, 38, 10, 80]
l.append(500)
print(l)
l.remove(28)
print(l)



#Create a tuple of your 3 favorite fruits. Try to change one fruit and see what happens (explain why).
t=("orange", "apple", "banana")
"""t.replace("apple","guava") #tuples are immutable
print(t) """
# Out:
# [56, 28, 38, 10, 80, 500]
# [56, 38, 10, 80, 500]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 16
#      14 #Create a tuple of your 3 favorite fruits. Try to change one fruit and see what happens (explain why).
#      15 t=("orange", "apple", "banana")
# ---> 16 t.replace("apple","guava")
#      17 print(t)
#
# AttributeError: 'tuple' object has no attribute 'replace'

# %%
""" Create a dictionary for a student
Print all keys, all values.
Add a new key "university": "XYZ"
Update age to 23 """
d={"name": "Aimen", "age": 22, "major": "Math"}
print(d.keys())
print(d.values())
print(d.items())
d1={"age": "23"}
d.update(d1)
print(d)
d["university"]= "UOL"
print(d)
# Out:
# dict_keys(['name', 'age', 'major'])
# dict_values(['Aimen', 22, 'Math'])
# dict_items([('name', 'Aimen'), ('age', 22), ('major', 'Math')])
# {'name': 'Aimen', 'age': '23', 'major': 'Math'}
# {'name': 'Aimen', 'age': '23', 'major': 'Math', 'university': 'UOL'}

# %%
""" Create a set of numbers 
Print the set
Add a new number
Remove a number """
s={1, 2, 3, 3, 4, 4}
print(s)
s.add(5)
s.remove(2)
print(s)
# Out:
# {1, 2, 3, 4}
# {1, 3, 4, 5}
